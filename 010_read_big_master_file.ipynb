# %% [markdown]
# Checking if the complete master file has the same format of the master file that I am reading from the class baby. If so, I can also read the maternal age and other properties that Prakash is asking in the demographics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as d

from datetime import date,datetime, timedelta

# %%
master = pd.read_excel("../TOST_data/TOST_State_Durham.xlsx",skip_blank_lines=True)

# %%
names = master['Study Number (Original)']

# %%
big_master = pd.read_excel("../TOST_data/TOST_Master_calgary.xlsx",skip_blank_lines=True)

# %%
big_names = big_master['Study Number (Original)']

# %%
for i in range(len(names)):
    if names[i]!= big_names[i]:
        print(names[i],big_names[i])
# Out:
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan

# %%
index = list(big_master['Study Number (Original)']).index('FMC003')

# %%
print(list(big_master['Study Number (Original)']).index('FMC004'))
print(list(master['Study Number (Original)']).index('FMC004'))
# Out:
# 1
# 1

# %%
for nm in big_master['Study Number (Original)']:
    if list(big_master['Study Number (Original)']).index(nm)==list(master['Study Number (Original)']).index(nm):
        print(type(nm))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# ...

# %%
big_master['Study Number (Original)'][0]
# Out:
# 'FMC003'

# %%
big_master['Maternal Age in Years'][0]
# Out:
# 33.0

# %%
big_master['Gesataional Diabetes'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)
