# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
df = pd.read_excel("../Sample - Superstore.xls")
#analogue to np.where (we are going to analyse only furniture)
furniture = df.loc[df['Category'] == 'Furniture']

# %%
furniture
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9962    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
# 9964    9965  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %%
len(furniture)
# Out:
# 2121

# %%
print('We have data for 4 years: ')
furniture['Order Date'].min(), furniture['Order Date'].max()
# Out:
# We have data for 4 years:
# (Timestamp('2014-01-06 00:00:00'), Timestamp('2017-12-30 00:00:00'))

# %%
# Remove the following columns
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID',
        'Customer Name', 'Segment', 'Country', 'City', 'State', 
        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 
        'Product Name', 'Quantity', 'Discount', 'Profit']
furniture.drop(cols, axis=1, inplace=True)
# sort data by date
furniture = furniture.sort_values('Order Date')
# check how many null data we have (should be zero)
furniture.isnull().sum()
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %%
# add up together all the sales in the same day (and adjust the index accordingly)
# And just keep the date and sales columns
furniture = furniture.groupby('Order Date')['Sales'].sum().reset_index()

# %%
len(furniture)
# Out:
# 889

# %%
# change the numerical index with the data
# (don't run it more than once)
furniture = furniture.set_index('Order Date')
furniture.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-07', '2014-01-10', '2014-01-11',
#                '2014-01-13', '2014-01-14', '2014-01-16', '2014-01-19',
#                '2014-01-20', '2014-01-21',
#                ...
#                '2017-12-18', '2017-12-19', '2017-12-21', '2017-12-22',
#                '2017-12-23', '2017-12-24', '2017-12-25', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=889, freq=None)

# %%
# we are resampling the data averaging in single month 
# MS is the string that define the resampling and it means single month 
# or at least this is what it does
y = furniture['Sales'].resample('MS').mean()

# %%
y
# Out:
# Order Date
# 2014-01-01     480.194231
# 2014-02-01     367.931600
# 2014-03-01     857.291529
# 2014-04-01     567.488357
# 2014-05-01     432.049188
# 2014-06-01     695.059242
# 2014-07-01     601.169500
# 2014-08-01     457.521656
# 2014-09-01     992.353367
# 2014-10-01     769.015437
# 2014-11-01     980.221486
# 2014-12-01    1532.298325
# 2015-01-01     978.328467
# 2015-02-01     522.395667
# 2015-03-01     781.236437
# 2015-04-01     805.822962
# 2015-05-01     624.996700
# 2015-06-01     428.565500
# 2015-07-01     719.706316
# 2015-08-01     602.412012
# 2015-09-01    1382.790684
# 2015-10-01     632.980184
# 2015-11-01    1286.701354
# 2015-12-01    1049.355418
# 2016-01-01     508.182867
# 2016-02-01     356.868273
# 2016-03-01     609.575810
# 2016-04-01     695.373158
# 2016-05-01     687.265227
# 2016-06-01     816.910750
# 2016-07-01     768.736412
# 2016-08-01     734.307782
# 2016-09-01    1135.953371
# 2016-10-01     624.872474
# 2016-11-01    1271.345152
# ...

# %%
y.plot()
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# # ARIMA MODEL

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0146      0.342      0.043      0.966      -0.655       0.684
# ma.L1         -1.0000      0.360     -2.781      0.005      -1.705      -0.295
# ar.S.L12      -0.0253      0.042     -0.609      0.543      -0.107       0.056
# sigma2      2.958e+04   1.22e-05   2.43e+09      0.000    2.96e+04    2.96e+04
# ...

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-6cfeaa52b7c1> in <module>()
# ----> 1 results.plot_diagnostics(figsize=(16, 8))
#       2 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize, truncate_endog_names)
#    4283         if resid.shape[0] < max(d, lags):
#    4284             raise ValueError(
# -> 4285                 "Length of endogenous variable must be larger the the number "
#    4286                 "of lags used in the model and the number of observations "
#    4287                 "burned in the log-likelihood calculation."
#
# ValueError: Length of endogenous variable must be larger the the number of lags used in the model and the number of observations burned in the log-likelihood calculation.

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()
